# %%
from PIL import Image
import numpy as np
import os

# %%
src = r'\\fatherserverdw\kyuex\clue images\annotations\roi\labeledmask_20rsf'
roilist = [_ for _ in os.listdir(src) if _.endswith('png')]

# %%
roiN = []
roiN2 = []
for idx,roi in enumerate(roilist):
    print(idx,'/',len(roilist))
    roitmp = Image.open(os.path.join(src,roi))
    roitmp = np.array(roitmp)
    roiN.append(len(np.unique(roitmp)))
    roiN2.append(np.max(roitmp))

np.max(roiN),np.max(roiN2)
# Out:
# 0 / 165
# 1 / 165
# 2 / 165
# 3 / 165
# 4 / 165
# 5 / 165
# 6 / 165
# 7 / 165
# 8 / 165
# 9 / 165
# 10 / 165
# 11 / 165
# 12 / 165
# 13 / 165
# 14 / 165
# 15 / 165
# 16 / 165
# 17 / 165
# 18 / 165
# 19 / 165
# 20 / 165
# 21 / 165
# 22 / 165
# 23 / 165
# 24 / 165
# 25 / 165
# 26 / 165
# 27 / 165
# 28 / 165
# 29 / 165
# 30 / 165
# 31 / 165
# 32 / 165
# 33 / 165
# 34 / 165
# 35 / 165
# 36 / 165
# 37 / 165
# 38 / 165
# 39 / 165
# 40 / 165
# 41 / 165
# 42 / 165
# 43 / 165
# 44 / 165
# 45 / 165
# 46 / 165
# 47 / 165
# 48 / 165
# 49 / 165
# 50 / 165
# 51 / 165
# 52 / 165
# 53 / 165
# 54 / 165
# 55 / 165
# 56 / 165
# 57 / 165
# 58 / 165
# 59 / 165
# 60 / 165
# 61 / 165
# 62 / 165
# 63 / 165
# 64 / 165
# 65 / 165
# 66 / 165
# 67 / 165
# 68 / 165
# 69 / 165
# 70 / 165
# 71 / 165
# 72 / 165
# 73 / 165
# 74 / 165
# 75 / 165
# 76 / 165
# 77 / 165
# 78 / 165
# 79 / 165
# 80 / 165
# 81 / 165
# 82 / 165
# 83 / 165
# 84 / 165
# 85 / 165
# 86 / 165
# 87 / 165
# 88 / 165
# 89 / 165
# 90 / 165
# ...
